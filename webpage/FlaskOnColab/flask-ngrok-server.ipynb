# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install flask-ngrok
# Out:
# Collecting flask-ngrok
#   Downloading flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from flask-ngrok) (2.23.0)
# Requirement already satisfied: Flask>=0.8 in c:\programdata\anaconda3\lib\site-packages (from flask-ngrok) (1.1.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->flask-ngrok) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->flask-ngrok) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->flask-ngrok) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->flask-ngrok) (2020.4.5.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.8->flask-ngrok) (2.11.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.8->flask-ngrok) (1.0.1)
# Requirement already satisfied: click>=5.1 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.8->flask-ngrok) (7.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.8->flask-ngrok) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=0.8->flask-ngrok) (1.1.1)
# Installing collected packages: flask-ngrok
# Successfully installed flask-ngrok-0.0.25

# %%
pip install -U flask-cors
# Out:
# Collecting flask-cors
#   Downloading Flask_Cors-3.0.8-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied, skipping upgrade: Six in c:\programdata\anaconda3\lib\site-packages (from flask-cors) (1.14.0)
# Requirement already satisfied, skipping upgrade: Flask>=0.9 in c:\programdata\anaconda3\lib\site-packages (from flask-cors) (1.1.1)
# Requirement already satisfied, skipping upgrade: click>=5.1 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.9->flask-cors) (7.0)
# Requirement already satisfied, skipping upgrade: Jinja2>=2.10.1 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.9->flask-cors) (2.11.1)
# Requirement already satisfied, skipping upgrade: itsdangerous>=0.24 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.9->flask-cors) (1.1.0)
# Requirement already satisfied, skipping upgrade: Werkzeug>=0.15 in c:\programdata\anaconda3\lib\site-packages (from Flask>=0.9->flask-cors) (1.0.1)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\programdata\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=0.9->flask-cors) (1.1.1)
# Installing collected packages: flask-cors
# Successfully installed flask-cors-3.0.8
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask_ngrok import run_with_ngrok
from flask import Flask
from flask import request, redirect
from flask import jsonify
from flask_cors import CORS, cross_origin

# %%
import cv2
from keras.models import load_model
import tensorflow as tf
import numpy as np
from PIL import Image
CATEGORIES=['CARS','CATS','DOGS','FLOWER','HUMANS','MOTOBIKES']
# Out:
# Using TensorFlow backend.

# %%
app = Flask(__name__)
#cors = CORS(app, resources={r"/foo": {"origins": "file://"}})
#app.config['CORS_HEADERS'] = 'Content-Type'
CORS(app)
run_with_ngrok(app)

# %%
model=tf.keras.models.load_model("D:\CODE\CNN\\final_project\\finalCNN\\trained-model.h5",compile=False)

# %%
def prepare(image):
    IMG_SIZE=256
    new_array= cv2.resize(np.float32(image),(IMG_SIZE,IMG_SIZE))
    return new_array.reshape(1,IMG_SIZE,IMG_SIZE,3)

# %%
@app.route("/predict", methods=['GET','POST'])
#@cross_origin(origin='*',headers=['Content-Type','Authorization'])
def predict():
    data =request.files["inpFile"]
    image = Image.open(request.files["inpFile"])
    image = np.array(image)
    predict=model.predict([prepare(image)])
    pred_name = CATEGORIES[np.argmax(predict)]
        
    response = {'finalResult' : pred_name}
    print(response) 
    return jsonify(response)

# %%
app.run()
# %tb
# Out:
# * Serving Flask app "__main__" (lazy loading)
#  * Environment: development
#  * Debug mode: on
#  * Restarting with windowsapi reloader
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
